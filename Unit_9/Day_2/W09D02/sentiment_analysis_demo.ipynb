# %% [markdown]
# # Sentiment Analysis Demo
#
# Notebook from [Eric Elmoznino](https://github.com/EricElmoznino/lighthouse_nlp_II).
#
# ![workflow](images/sentiment_workflow.jpg)

# %% [markdown]
# # Loading the dataset
#
# Dataset is downloaded from [here](https://www.kaggle.com/code/kerneler/starter-imdb-master-csv-19b6829a-2/data).

# %%
import pandas as pd
imdb_df = pd.read_csv('data/imdb_sentiment.csv', encoding = "ISO-8859-1")
imdb_df.columns = ['review', 'label']
imdb_df.head()
# Out:
#                                               review     label
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
imdb_df['label'].value_counts()
# Out:
# positive    25000
# negative    25000
# Name: label, dtype: int64

# %%
# Only consider positive and negative reviews
imdb_df = imdb_df[imdb_df['label'].str.startswith(('pos','neg'))]

# %% [markdown]
# # Preprocessing to a numeric representation
#
# The current data is in the form of moview reviews (text paragraphs) and their targets (`pos` or `neg`).
# We need to encode movie reviews into feature vectors so that we can train supervised machine learning models with `scikit-learn`.
# How can we do this?
#
# #### Create binarized word frequency counts (`X_binary`)
# Turn the text into sparse vector of word frequency counts using [CountVectorizer](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html) from  `scikit-learn`.
#
# When you reproduce this, explore the arguments of `CountVectorizer` (e.g., [`stop_words`](https://scikit-learn.org/stable/modules/feature_extraction.html#stop-words), `ngram_range`, `max_features`, `min_df`, `tokenizer`, and `binary`).
#
# The intuition behind using binarized representation is that for sentiment analysis word occurrence may matter more than word frequency. For instance, the occurrence of the word _excellent_ tells us a lot and the fact that it occurs four times may not tell us much more. This is just a hypothesis that you could test, however.

# %%
# For tokenization
import nltk

# For converting words into frequency counts
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
# First step in pipeline
# Keep words that appear in atleast 2 documents, keeps 5000 most common words
preprocessor = CountVectorizer(min_df=2, tokenizer=nltk.word_tokenize, max_features=5000, binary=True)
# preprocessor = TfidfVectorizer(min_df=2, tokenizer=nltk.word_tokenize, max_features=5000)

# %%
# Demo the preprocessor:
X_example = preprocessor.fit_transform(imdb_df['review'].iloc[:1000])
print(f'Preprocessing output shape: {X_example.shape}')

# Show the process for the first datapoint
first_datapoint = imdb_df['review'].iloc[0]
print(f'First datapoint: {first_datapoint[:100]}')

first_tokens = nltk.word_tokenize(first_datapoint)
print(f'First datapoint tokens: {first_tokens[:10]}')

first_bow = preprocessor.transform([first_datapoint])
first_bow.maxprint = 5  # Change how many of the non-zero elements are printing to not clutter the notebook
print(f'First datapoint Binary Bag of Words (sparse) representation:\n{first_bow}')
print(f'First datapoint Binary Bag of Words (dense) representation:\n{first_bow.todense()}')

preprocessor.vocabulary_
# Out:
# C:\Users\dell\anaconda3\envs\auto\lib\site-packages\sklearn\feature_extraction\text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Preprocessing output shape: (1000, 5000)
# First datapoint: One of the other reviewers has mentioned that after watching just 1 Oz episode you'll be hooked. The
# First datapoint tokens: ['One', 'of', 'the', 'other', 'reviewers', 'has', 'mentioned', 'that', 'after', 'watching']
# First datapoint Binary Bag of Words (sparse) representation:
#   (0, 8)	1
#   (0, 14)	1
#   :	:
#   (0, 4962)	1
#   (0, 4986)	1
#   (0, 4989)	1
# First datapoint Binary Bag of Words (dense) representation:
# [[0 0 0 ... 0 0 0]]
# {'one': 3043,
#  'of': 3013,
#  'the': 4462,
#  'other': 3076,
#  'reviewers': 3665,
#  'has': 2083,
#  'mentioned': 2754,
#  'that': 4459,
#  'after': 206,
#  'watching': 4841,
#  'just': 2437,
#  '1': 29,
#  'oz': 3112,
#  'episode': 1529,
#  'you': 4986,
#  "'ll": 8,
#  'be': 491,
#  'hooked': 2176,
#  '.': 20,
#  'they': 4483,
#  'are': 351,
#  'right': 3683,
#  ',': 17,
#  'as': 372,
#  'this': 4495,
#  'is': 2365,
#  'exactly': 1572,
#  'what': 4879,
#  'happened': 2069,
#  'with': 4923,
#  'me.': 2726,
#  '<': 94,
#  'br': 619,
#  '/': 27,
#  '>': 95,
#  'first': 1762,
#  'thing': 4487,
#  'struck': 4234,
#  'me': 2725,
#  'about': 105,
#  'was': 4833,
#  'its': 2377,
#  'and': 291,
#  'scenes': 3815,
#  'violence': 4782,
#  'which': 4888,
#  'set': 3906,
#  'in': 2272,
#  'from': 1867,
#  'word': 4945,
#  'go': 1958,
#  'trust': 4651,
#  'not': 2957,
#  'a': 98,
#  'show': 3956,
#  'for': 1803,
#  'hearted': 2104,
#  'or': 3062,
#  'pulls': 3458,
#  'no': 2937,
#  'regards': 3571,
#  'to': 4546,
#  'drugs': 1394,
#  'sex': 3916,
#  'hardcore': 2077,
#  'classic': 858,
#  'use': 4733,
#  'it': 2372,
#  'called': 691,
#  'given': 1943,
#  'oswald': 3075,
#  'maximum': 2722,
#  'security': 3855,
#  'state': 4173,
#  'focuses': 1785,
#  'mainly': 2671,
#  'on': 3039,
#  'city': 849,
#  'an': 289,
#  'experimental': 1609,
#  'section': 3854,
#  'prison': 3396,
#  'where': 4885,
#  'all': 247,
#  'cells': 762,
#  'have': 2091,
#  'glass': 1950,
#  'fronts': 1869,
#  'face': 1647,
#  'so': 4054,
#  'high': 2138,
#  'em': 1463,
#  'home': 2168,
#  'many': 2691,
#  '..': 21,
#  'christians': 833,
#  'irish': 2359,
#  'more': 2833,
#  '....': 23,
#  'death': 1148,
#  'dodgy': 1337,
#  'never': 2925,
#  'far': 1687,
#  'i': 2223,
#  'would': 4962,
#  'say': 3804,
#  'main': 2670,
#  'appeal': 332,
#  'due': 1398,
#  'fact': 1652,
#  'goes': 1967,
#  'shows': 3964,
#  "n't": 2885,
#  'dare': 1119,
#  'forget': 1812,
#  'pretty': 3374,
#  'pictures': 3243,
#  'mainstream': 2672,
#  'audiences': 413,
#  'charm': 795,
#  'romance': 3726,
#  '...': 22,
#  'does': 1338,
#  'mess': 2759,
#  'around': 361,
#  'ever': 1561,
#  'saw': 3803,
#  'nasty': 2895,
#  'surreal': 4329,
#  'could': 1027,
#  'ready': 3530,
#  'but': 680,
#  'watched': 4840,
#  'developed': 1244,
#  'taste': 4399,
#  'got': 1984,
#  'accustomed': 138,
#  'levels': 2564,
#  'graphic': 1997,
#  '(': 14,
#  'crooked': 1079,
#  'who': 4893,
#  'sold': 4064,
#  'out': 3084,
#  'kill': 2460,
#  'order': 3065,
#  'get': 1928,
#  'away': 435,
#  'well': 4869,
#  'middle': 2773,
#  'class': 857,
#  'being': 521,
#  'turned': 4660,
#  'into': 2341,
#  'their': 4468,
#  'lack': 2489,
#  'street': 4221,
#  'skills': 4022,
#  'experience': 1605,
#  ')': 15,
#  'may': 2723,
#  'become': 504,
#  'comfortable': 924,
#  'uncomfortable': 4684,
#  'viewing': 4776,
#  'thats': 4461,
#  'if': 2235,
#  'can': 702,
#  'touch': 4579,
#  'your': 4989,
#  'darker': 1122,
#  'side': 3971,
#  'wonderful': 4936,
#  'little': 2601,
#  'production': 3413,
#  'filming': 1741,
#  'technique': 4416,
#  'very': 4761,
#  'fashion': 1692,
#  'gives': 1944,
#  'sometimes': 4079,
#  'sense': 3882,
#  'realism': 3535,
#  'entire': 1520,
#  'piece': 3245,
#  'actors': 149,
#  'extremely': 1641,
#  'michael': 2769,
#  'only': 3048,
#  '``': 97,
#  "''": 6,
#  'he': 2094,
#  'voices': 4796,
#  'down': 1356,
#  'pat': 3168,
#  'too': 4565,
#  '!': 0,
#  'truly': 4650,
#  'see': 3857,
#  'editing': 1436,
#  'by': 683,
#  'references': 3561,
#  'williams': 4908,
#  "'": 5,
#  'worth': 4959,
#  'written': 4972,
#  'performed': 3196,
#  'great': 2004,
#  'master': 2710,
#  "'s": 11,
#  'comedy': 922,
#  'his': 2150,
#  'life': 2572,
#  'really': 3542,
#  'comes': 923,
#  'things': 4488,
#  ':': 92,
#  'fantasy': 1686,
#  'guard': 2032,
#  'rather': 3516,
#  'than': 4455,
#  'traditional': 4599,
#  'techniques': 4417,
#  'remains': 3596,
#  'solid': 4069,
#  'then': 4475,
#  'plays': 3275,
#  'our': 3082,
#  'knowledge': 2480,
#  'senses': 3883,
#  'particularly': 3154,
#  'sets': 3907,
#  'flat': 1771,
#  'every': 1562,
#  'surface': 4321,
#  'terribly': 4443,
#  'done': 1347,
#  'thought': 4501,
#  'way': 4845,
#  'spend': 4125,
#  'time': 4534,
#  'hot': 2194,
#  'summer': 4300,
#  'weekend': 4864,
#  'sitting': 4011,
#  'air': 225,
#  'theater': 4463,
#  'plot': 3282,
#  'simplistic': 3993,
#  'dialogue': 1254,
#  'witty': 4928,
#  'characters': 789,
#  'likable': 2580,
#  'even': 1556,
#  'suspected': 4340,
#  'serial': 3896,
#  'killer': 2462,
#  'while': 4889,
#  'some': 4073,
#  'disappointed': 1295,
#  'when': 4883,
#  'realize': 3539,
#  'match': 2713,
#  'point': 3288,
#  '2': 55,
#  'risk': 3697,
#  'addiction': 166,
#  'proof': 3432,
#  'woody': 4944,
#  'allen': 250,
#  'still': 4199,
#  'fully': 1875,
#  'control': 999,
#  'style': 4257,
#  'us': 4731,
#  'grown': 2026,
#  'love.': 2642,
#  'most': 2838,
#  "'d": 7,
#  'laughed': 2514,
#  'at': 389,
#  'comedies': 921,
#  'years': 4979,
#  'decade': 1153,
#  '?': 96,
#  "'ve": 13,
#  'been': 509,
#  'impressed': 2268,
#  'she': 3933,
#  'managed': 2686,
#  'tone': 4558,
#  'her': 2124,
#  'sexy': 3919,
#  'image': 2247,
#  'average': 428,
#  'spirited': 4136,
#  'young': 4987,
#  'career': 721,
#  'devil': 1249,
#  'wears': 4860,
#  'interesting': 2334,
#  'superman': 4312,
#  'friends': 1864,
#  'basically': 483,
#  'there': 4478,
#  'family': 1677,
#  'boy': 616,
#  'thinks': 4492,
#  'zombie': 4995,
#  'closet': 883,
#  '&': 4,
#  'parents': 3146,
#  'fighting': 1730,
#  'time.': 4535,
#  'movie': 2853,
#  'soap': 4057,
#  'opera': 3054,
#  'suddenly': 4281,
#  'decides': 1159,
#  'ok': 3027,
#  "'re": 10,
#  'going': 1968,
#  'make': 2676,
#  'film': 1737,
#  'must': 2878,
#  'decide': 1157,
#  'thriller': 4512,
#  'drama': 1368,
#  'watchable': 4839,
#  'like': 2581,
#  'real': 3531,
#  'we': 4849,
#  'totally': 4578,
#  'ruins': 3758,
#  'expected': 1601,
#  'similar': 3988,
#  'instead': 2316,
#  'meaningless': 2729,
#  '3': 65,
#  '10': 33,
#  'playing': 3274,
#  'descent': 1208,
#  'dialogs': 1253,
#  'shots': 3953,
#  'ignore': 2238,
#  'them': 4469,
#  'love': 2641,
#  'money': 2821,
#  'visually': 4790,
#  'stunning': 4250,
#  'watch': 4838,
#  'mr.': 2859,
#  'offers': 3020,
#  'vivid': 4793,
#  'portrait': 3317,
#  'human': 2203,
#  'relations': 3580,
#  'seems': 3865,
#  'telling': 4430,
#  'power': 3339,
#  'success': 4273,
#  'do': 1333,
#  'people': 3185,
#  'different': 1268,
#  'situations': 4013,
#  'encounter': 1480,
#  'play': 3270,
#  'same': 3788,
#  'theme': 4471,
#  'director': 1288,
#  'action': 146,
#  'present': 3362,
#  'new': 2927,
#  'york': 4985,
#  'these': 4482,
#  'meet': 2739,
#  'connect': 973,
#  'each': 1408,
#  'connected': 974,
#  'another': 314,
#  'next': 2930,
#  'person': 3205,
#  'know': 2478,
#  'previous': 3379,
#  'contact': 984,
#  'sophisticated': 4088,
#  'look': 2621,
#  'taken': 4380,
#  'how': 2199,
#  'live': 2602,
#  'world': 4952,
#  'own': 3111,
#  'gets': 1929,
#  'souls': 4096,
#  'picture': 3241,
#  'loneliness': 2616,
#  'big': 547,
#  'best': 537,
#  'place': 3256,
#  'find': 1751,
#  'sincere': 3998,
#  'case': 744,
#  'acting': 145,
#  'good': 1975,
#  'under': 4687,
#  'direction': 1286,
#  'steve': 4193,
#  'carol': 732,
#  'kane': 2441,
#  'adrian': 183,
#  'rest': 3645,
#  'talented': 4385,
#  'cast': 748,
#  'come': 918,
#  'wish': 4919,
#  'luck': 2651,
#  'work': 4947,
#  'probably': 3401,
#  'my': 2880,
#  'favorite': 1700,
#  'story': 4212,
#  'sacrifice': 3774,
#  'noble': 2938,
#  'cause': 758,
#  'boring': 601,
#  'old': 3030,
#  'despite': 1228,
#  'having': 2092,
#  'seen': 3866,
#  '15': 40,
#  'times': 4536,
#  'last': 2504,
#  '25': 63,
#  'paul': 3176,
#  'performance': 3194,
#  'brings': 645,
#  'tears': 4411,
#  'eyes': 1643,
#  'bette': 540,
#  'davis': 1131,
#  'few': 1723,
#  'sympathetic': 4364,
#  'roles': 3720,
#  'delight': 1178,
#  'kids': 2459,
#  'says': 3806,
#  'children': 818,
#  'makes': 2680,
#  'fun': 1876,
#  'mother': 2840,
#  'slow': 4034,
#  'happening': 2070,
#  'believable': 524,
#  'had': 2049,
#  'dozen': 1360,
#  'thumbs': 4524,
#  'up': 4725,
#  'sure': 4319,
#  'dated': 1127,
#  'series': 3898,
#  'tech': 4412,
#  'today': 4548,
#  'bring': 643,
#  'back': 450,
#  'kid': 2457,
#  'grew': 2011,
#  'black': 561,
#  'white': 4891,
#  'tv': 4663,
#  'were': 4874,
#  'hero': 2128,
#  'vote': 4798,
#  'sea': 3842,
#  'need': 2910,
#  'change': 780,
#  'pace': 3115,
#  'water': 4842,
#  'thank': 4456,
#  'view': 4772,
#  'any': 319,
#  'believe': 525,
#  'wan': 4815,
#  'na': 2886,
#  'nice': 2931,
#  'read': 3528,
#  'plus': 3285,
#  'points': 3291,
#  'lines': 2592,
#  'let': 2558,
#  'leave': 2538,
#  'doubt': 1354,
#  'quit': 3488,
#  'lets': 2560,
#  'amazing': 273,
#  'fresh': 1858,
#  'innovative': 2302,
#  'idea': 2228,
#  '70': 82,
#  'aired': 226,
#  '7': 80,
#  '8': 84,
#  'brilliant': 641,
#  'dropped': 1391,
#  'off': 3014,
#  'funny': 1881,
#  'anymore': 321,
#  'continued': 993,
#  'further': 1883,
#  'complete': 950,
#  'waste': 4836,
#  'today.': 4549,
#  'disgraceful': 1310,
#  'fallen': 1669,
#  'writing': 4971,
#  'painfully': 3127,
#  'bad': 454,
#  'performances': 3195,
#  'almost': 257,
#  '-': 18,
#  'mildly': 2778,
#  'entertaining': 1517,
#  'hard': 2076,
#  'creator': 1059,
#  'original': 3069,
#  'also': 263,
#  'chose': 828,
#  'band': 464,
#  'followed': 1790,
#  'recognize': 3552,
#  'such': 4276,
#  'brilliance': 640,
#  'fit': 1764,
#  'replace': 3618,
#  'mediocrity': 2738,
#  'felt': 1719,
#  'give': 1942,
#  'stars': 4168,
#  'respect': 3640,
#  'made': 2664,
#  'huge': 2201,
#  'now': 2976,
#  'awful': 438,
#  'ca': 685,
#  'positive': 3325,
#  'comments': 931,
#  'here': 2126,
#  'looking': 2623,
#  'forward': 1831,
#  'mistake': 2807,
#  'films': 1744,
#  'worst': 4958,
#  'pacing': 3117,
#  'storyline': 4214,
#  'soundtrack': 4100,
#  'song': 4083,
#  'lame': 2496,
#  'country': 1032,
#  'tune': 4655,
#  'played': 3271,
#  'less': 2554,
#  'four': 1837,
#  'looks': 2624,
#  'cheap': 802,
#  'extreme': 1640,
#  'rarely': 3513,
#  'happy': 2075,
#  'end': 1483,
#  'credits': 1064,
#  'prevents': 3376,
#  'giving': 1945,
#  'least': 2537,
#  'making': 2682,
#  'bit': 556,
#  'effort': 1447,
#  'gut': 2043,
#  'laughter': 2517,
#  'will': 4906,
#  'hell': 2115,
#  'mom': 2817,
#  'liked': 2582,
#  'it.': 2373,
#  'camp': 700,
#  'alien': 243,
#  'those': 4499,
#  'quirky': 3487,
#  'humour': 2211,
#  'based': 480,
#  'everything': 1565,
#  'actual': 153,
#  'odd': 3010,
#  'did': 1261,
#  'jokes': 2416,
#  'low': 2648,
#  'budget': 662,
#  'problem': 3402,
#  'itself': 2378,
#  'eventually': 1560,
#  'lost': 2633,
#  'imagine': 2254,
#  'currently': 1098,
#  'something': 4077,
#  'better': 541,
#  'try': 4653,
#  'brother': 650,
#  'planet': 3265,
#  '12': 37,
#  'came': 695,
#  'recall': 3546,
#  'scene': 3813,
#  'bird': 554,
#  'eating': 1426,
#  'men': 2750,
#  'horror': 2188,
#  'cheesy': 809,
#  'b': 442,
#  'saturday': 3799,
#  'tired': 4542,
#  'formula': 1823,
#  'monster': 2823,
#  'type': 4671,
#  'movies': 2855,
#  'usually': 4740,
#  'included': 2277,
#  'beautiful': 499,
#  'woman': 4931,
#  'might': 2775,
#  'daughter': 1129,
#  'professor': 3417,
#  'died': 1263,
#  'care': 719,
#  'much': 2863,
#  'romantic': 3728,
#  'angle': 299,
#  'year': 4978,
#  'predictable': 3352,
#  'plots': 3283,
#  'unintentional': 4706,
#  'later': 2508,
#  'psycho': 3451,
#  'loved': 2643,
#  'star': 4165,
#  'early': 1414,
#  'sat': 3793,
#  'took': 4567,
#  'notice': 2966,
#  'since': 3997,
#  'scary': 3810,
#  'possible': 3330,
#  'rules': 3760,
#  'im': 2246,
#  'fan': 1680,
#  'boll': 589,
#  'again': 209,
#  'enjoyed': 1504,
#  'maybe': 2724,
#  'apparently': 331,
#  'bought': 611,
#  'rights': 3686,
#  'cry': 1087,
#  'long': 2618,
#  'ago': 218,
#  'before': 511,
#  'game': 1895,
#  'killing': 2464,
#  'secret': 3853,
#  'research': 3632,
#  'island': 2367,
#  'should': 3954,
#  'warned': 4828,
#  'mr': 2858,
#  'together': 4551,
#  'along': 259,
#  'feeling': 1712,
#  'three': 4509,
#  'players': 3273,
#  'names': 2892,
#  'actually': 154,
#  'tale': 4383,
#  'jack': 2380,
#  'yes': 4982,
#  'german': 1925,
#  'however': 2200,
#  'staying': 4181,
#  'true': 4649,
#  'whole': 4895,
#  'perspective': 3212,
#  'looked': 2622,
#  'kicking': 2455,
#  '*': 16,
#  'beyond': 545,
#  'demented': 1188,
#  'evil': 1568,
#  'mad': 2663,
#  'scientist': 3822,
#  'dr.': 1362,
#  'performing': 3199,
#  'reminds': 3603,
#  'spoiler': 4142,
#  'reason': 3544,
#  'rich': 3672,
#  'gone': 1974,
#  'started': 4170,
#  'stay': 4179,
#  'shenanigans': 3936,
#  'delivers': 1184,
#  'meaning': 2728,
#  'areas': 353,
#  'boat': 585,
#  'until': 4722,
#  'squad': 4152,
#  'enters': 1514,
#  'laugh': 2511,
#  'reeks': 3559,
#  'r': 3492,
#  'take': 4379,
#  'ahead': 221,
#  'annoying': 312,
#  'sidekick': 3973,
#  'shoot': 3943,
#  'him': 2145,
#  'minutes': 2795,
#  'screen': 3832,
#  'shakespeare': 3924,
#  'appreciate': 341,
#  'trying': 4654,
#  'masses': 2708,
#  'why': 4898,
#  'ruin': 3756,
#  'good.': 1977,
#  'because': 503,
#  "'the": 12,
#  'scottish': 3828,
#  'certain': 770,
#  'hence': 2122,
#  'tried': 4637,
#  'victorian': 4769,
#  'era.': 1535,
#  'words': 4946,
#  'improve': 2271,
#  'write': 4966,
#  'ten': 4433,
#  'text': 4454,
#  'english': 1500,
#  'keep': 2445,
#  'saying': 3805,
#  'cut': 1100,
#  'fantastic': 1684,
#  'famous': 1679,
#  'george': 1922,
#  'clooney': 876,
#  "'m": 9,
#  'roll': 3721,
#  'man': 2684,
#  'constant': 980,
#  'sorrow': 4090,
#  'everybody': 1563,
#  'kind': 2468,
#  'drawn': 1373,
#  'amateurish': 271,
#  'unbelievable': 4681,
#  'bits': 558,
#  'sort': 4092,
#  'school': 3817,
#  'project': 3425,
#  'thinking': 4491,
#  'stock': 4201,
#  'bizarre': 560,
#  'supposed': 4317,
#  'town': 4589,
#  'involved': 2354,
#  'lessons': 2557,
#  'learned': 2534,
#  'quite': 3489,
#  'ridiculous': 3680,
#  'lots': 2635,
#  'skin': 4023,
#  'nonsense': 2949,
#  'relationship': 3581,
#  'nowhere': 2978,
#  'encounters': 1481,
#  'absurd': 112,
#  'dance': 1113,
#  'stereotyped': 4190,
#  'pass': 3159,
#  'million': 2783,
#  'miles': 2780,
#  'wasted': 4837,
#  'spent': 4128,
#  'africa': 204,
#  '.....': 24,
#  'simply': 3994,
#  'fails': 1661,
#  'capture': 713,
#  'terror': 4446,
#  'title': 4543,
#  'excellent': 1575,
#  'always': 267,
#  'holds': 2161,
#  'exception': 1577,
#  'owen': 3110,
#  'wilson': 4910,
#  'feel': 1711,
#  'character': 787,
#  'luke': 2655,
#  'major': 2674,
#  'fault': 1697,
#  'version': 4758,
#  'jackson': 2382,
#  'attempts': 402,
#  'earlier': 1413,
#  'trade': 4597,
#  'special': 4113,
#  'effects': 1446,
#  'enjoy': 1502,
#  'older': 3033,
#  'top': 4568,
#  'horrible': 2184,
#  'minute': 2794,
#  'fight': 1729,
#  'chance': 778,
#  'development': 1246,
#  'running': 3762,
#  'sword': 4361,
#  'emotional': 1469,
#  'attachment': 394,
#  'except': 1576,
#  'machine': 2662,
#  'wanted': 4820,
#  'destroy': 1231,
#  'blatantly': 570,
#  'stolen': 4203,
#  'wars': 4832,
#  'matrix': 2715,
#  'examples': 1574,
#  'ghost': 1931,
#  'final': 1746,
#  'spider': 4129,
#  'beginning': 515,
#  'attacked': 396,
#  'return': 3653,
#  'kings': 2473,
#  'wood': 4941,
#  'victim': 4766,
#  'both': 606,
#  'wait': 4804,
#  '......': 25,
#  'vs.': 4800,
#  'humans': 2206,
#  'terminator': 4440,
#  'someone': 4076,
#  'tell': 4428,
#  'nazi': 2902,
#  'juvenile': 2440,
#  'line': 2590,
#  'rushed': 3767,
#  'conclusion': 962,
#  'adult': 185,
#  'either': 1452,
#  'disappointment': 1297,
#  'save': 3800,
#  'remember': 3599,
#  'cinema': 840,
#  'dark': 1121,
#  'places': 3258,
#  'nervous': 2921,
#  'dad': 1106,
#  'sister': 4008,
#  'england': 1499,
#  'snow': 4052,
#  'appearance': 335,
#  'grizzly': 2018,
#  'adams': 157,
#  'actor': 148,
#  'dan': 1112,
#  'think': 4490,
#  'shot': 3952,
#  'dies': 1264,
#  'anyone': 322,
#  'knows': 2482,
#  'dvd': 1403,
#  'etc': 1551,
#  'please': 3278,
#  'club': 889,
#  'shame': 3928,
#  'nearest': 2905,
#  '20': 58,
#  'hear': 2100,
#  'others': 3078,
#  'against': 211,
#  'nominated': 2944,
#  'golden': 1971,
#  'globe': 1954,
#  'female': 1720,
#  'recognition': 3551,
#  'complaint': 948,
#  'liberties': 2568,
#  'facts': 1655,
#  ';': 93,
#  'perfectly': 3192,
#  'fine': 1754,
#  '--': 19,
#  'accounts': 134,
#  'artist': 369,
#  'script': 3838,
#  'suppose': 4316,
#  'enough': 1507,
#  'naked': 2888,
#  'factual': 1656,
#  'summary': 4299,
#  'saved': 3801,
#  'ourselves': 3083,
#  'couple': 1035,
#  'hours': 2197,
#  'die': 1262,
#  'sequels': 3893,
#  'surprise': 4324,
#  'wrong': 4973,
#  'guy': 2045,
#  'concept': 957,
#  'cliffhanger': 868,
#  'mountain': 2845,
#  'rescue': 3631,
#  'dream': 1376,
#  'especially': 1543,
#  'expert': 1610,
#  'facial': 1650,
#  'expressions': 1634,
#  'full': 1874,
#  'pile': 3249,
#  'junk': 2435,
#  'horse': 2190,
#  'lovable': 2640,
#  'undeniably': 4686,
#  'romp': 3731,
#  'plenty': 3281,
#  'thrills': 4515,
#  'unintentionally': 4707,
#  'john': 2410,
#  'box': 614,
#  'permanently': 3203,
#  'hapless': 2067,
#  'agent': 214,
#  'henry': 2123,
#  'noteworthy': 2964,
#  'cringe-worthy': 1070,
#  'constantly': 981,
#  'painful': 3126,
#  'disbelief': 1299,
#  'hurt': 2217,
#  'anybody': 320,
#  'whilst': 4890,
#  'surely': 4320,
#  'ralph': 3505,
#  'frank': 1847,
#  'girl': 1939,
#  'mention': 2753,
#  'former': 1822,
#  'burning': 673,
#  'craig': 1046,
#  'using': 4738,
#  'football': 1802,
#  'help': 2116,
#  'needed': 2911,
#  'cares': 725,
#  'happen': 2068,
#  'lower': 2649,
#  'expectations': 1600,
#  'turn': 4659,
#  'wearing': 4859,
#  'helicopter': 2114,
#  'terrible': 4442,
#  'b-movie': 443,
#  'aspects': 381,
#  'sequences': 3895,
#  'fake': 1667,
#  '.......': 26,
#  'packed': 3120,
#  'crappy': 1048,
#  'one-liners': 3045,
#  'respectable': 3641,
#  'amusing': 287,
#  'towards': 4587,
#  'women': 4932,
#  'utterly': 4742,
#  'unattractive': 4680,
#  'appear': 334,
#  'weird': 4867,
#  'costumes': 1026,
#  'fail': 1658,
#  'miserably': 2800,
#  'b-movies': 444,
#  'laughs': 2516,
#  'absolutely': 110,
#  'wo': 4930,
#  'regret': 3573,
#  'carries': 737,
#  'although': 265,
#  'anything': 323,
#  'music': 2875,
#  'takes': 4381,
#  ...}

# %% [markdown]
# ### Question
# What is the disadvantage of using something like a *Bag of Words* representation for the documents in sentiment analysis?
#
# ### Answer
# You lose the word order, and therefore the syntax. For instance, negation is lost.

# %% [markdown]
# # Modeling

# %%
from sklearn.naive_bayes import BernoulliNB # Bernoulli because we have binary features
from sklearn.pipeline import Pipeline

pipeline = Pipeline([('preprocessing', preprocessor), 
                     ('model', BernoulliNB())])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(imdb_df['review'], imdb_df['label'], test_size=0.20, random_state=27)

# %%
pipeline.fit(X_train, y_train)
train_accuracy = pipeline.score(X_train, y_train)
test_accuracy = pipeline.score(X_test, y_test)

print(f'Train accuracy:\t{train_accuracy}')
print(f'Test accuracy:\t{test_accuracy}')
# Out:
# C:\Users\dell\anaconda3\envs\auto\lib\site-packages\sklearn\feature_extraction\text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Train accuracy:	0.851875
# Test accuracy:	0.8432

# %%
pipeline.predict()

# %%
# Set up the TF-IDF vectorizer
# Keep words that appear in atleast 2 documents, keeps 5000 most common words
preprocessor = TfidfVectorizer(min_df=2, tokenizer=nltk.word_tokenize, max_features=5000, ngram_range=(1,2), stop_words='english')

# %%
# fit and transform data
X = preprocessor.fit_transform(imdb_df['review'])
# Out:
# C:\Users\dell\anaconda3\envs\auto\lib\site-packages\sklearn\feature_extraction\text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
# split data
X_train, X_test, y_train, y_test = train_test_split(X.toarray(), imdb_df['label'], test_size=0.20, random_state=27)

# %%
from sklearn.naive_bayes import GaussianNB

model = GaussianNB()
model.fit(X_train,y_train)

train_accuracy = model.score(X_train, y_train)
test_accuracy = model.score(X_test, y_test)

print(f'Train accuracy:\t{train_accuracy}')
print(f'Test accuracy:\t{test_accuracy}')
# Out:
# Train accuracy:	0.860475
# Test accuracy:	0.8407
