# %% [markdown]
# # Pandas Reshaping

# %%
import pandas as pd, numpy as np

# %% [markdown]
# ### Stack
# - The stack() method "compresses" a level in the DataFrame's columns

# %%
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz',
                         'foo', 'foo', 'qux', 'qux'],
                        ['one', 'two', 'one', 'two',
                         'one', 'two', 'one', 'two']]))
tuples
# Out:
# [('bar', 'one'),
#  ('bar', 'two'),
#  ('baz', 'one'),
#  ('baz', 'two'),
#  ('foo', 'one'),
#  ('foo', 'two'),
#  ('qux', 'one'),
#  ('qux', 'two')]

# %%
index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])
index
# Out:
# MultiIndex([('bar', 'one'),
#             ('bar', 'two'),
#             ('baz', 'one'),
#             ('baz', 'two'),
#             ('foo', 'one'),
#             ('foo', 'two'),
#             ('qux', 'one'),
#             ('qux', 'two')],
#            names=['first', 'second'])

# %%
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=['A', 'B'])
df2 = df[:4]
df
# Out:
#                      A         B
# first second
# bar   one     0.117071 -0.526528
#       two    -0.128731 -0.342161
# baz   one    -1.465910  2.694722
#       two     0.873542  0.175771
# foo   one     0.089678 -0.072269
#       two     0.216068 -0.930282
# qux   one    -1.019816  1.135911
#       two     0.036613  0.980198

# %%
df2

# we are going to use the stack() function to "compress" the columns into the index.
# Out:
#                      A         B
# first second
# bar   one     0.117071 -0.526528
#       two    -0.128731 -0.342161
# baz   one    -1.465910  2.694722
#       two     0.873542  0.175771

# %%
stacked = df2.stack()

# %%
stacked
# Out:
# first  second
# bar    one     A    0.117071
#                B   -0.526528
#        two     A   -0.128731
#                B   -0.342161
# baz    one     A   -1.465910
#                B    2.694722
#        two     A    0.873542
#                B    0.175771
# dtype: float64

# %% [markdown]
# ### Unstack
# - the inverse operation of stack() is unstack(), which by default unstacks the last level:

# %%
stacked.unstack() # This is simmilar to df2
# Out:
#                      A         B
# first second
# bar   one     0.117071 -0.526528
#       two    -0.128731 -0.342161
# baz   one    -1.465910  2.694722
#       two     0.873542  0.175771

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A  0.117071 -0.128731
#       B -0.526528 -0.342161
# baz   A -1.465910  0.873542
#       B  2.694722  0.175771

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A  0.117071 -1.465910
#        B -0.526528  2.694722
# two    A -0.128731  0.873542
#        B -0.342161  0.175771

# %% [markdown]
# ### Pivot Tables

# %%
df = pd.DataFrame({'A': ['one', 'one', 'two', 'three'] * 3,
                       'B': ['A', 'B', 'C'] * 4,
                       'C': ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
                       'D': np.random.randn(12),
                       'E': np.random.randn(12)})

# %%
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -0.501594  0.146318
# 1     one  B  foo  0.712424 -0.384372
# 2     two  C  foo -0.440551 -0.162417
# 3   three  A  bar -1.112508  0.708032
# 4     one  B  bar  0.091361 -0.436871
# 5     one  C  bar -0.129742  0.409215
# 6     two  A  foo  0.860685  1.293326
# 7   three  B  foo  1.770378 -0.169101
# 8     one  C  foo  1.003843  1.783656
# 9     one  A  bar -0.013305 -1.140718
# 10    two  B  bar  0.203167  0.658078
# 11  three  C  bar -0.732157 -1.870291

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
# Out:
# C             bar       foo
# A     B
# one   A -0.013305 -0.501594
#       B  0.091361  0.712424
#       C -0.129742  1.003843
# three A -1.112508       NaN
#       B       NaN  1.770378
#       C -0.732157       NaN
# two   A       NaN  0.860685
#       B  0.203167       NaN
#       C       NaN -0.440551
