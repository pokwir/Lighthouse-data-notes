# %% [markdown]
# # Keras Demo
# ## Credit: Eric Elmoznino

# %%
# !pip install tensorflow

# %% [markdown]
# ## Prepare the data
# Predict wage_per_hour from various features.

# %%
import pandas as pd

df = pd.read_csv('data/hourly_wages_data.csv')
df.head()
# Out:
#    wage_per_hour  union  education_yrs  experience_yrs  age  female  marr  \
# 0           5.10      0              8              21   35       1     1
# 1           4.95      0              9              42   57       1     1
# 2           6.67      0             12               1   19       0     0
# 3           4.00      0             12               4   22       0     0
# 4           7.50      0             12              17   35       0     1
#
#    south  manufacturing  construction
# 0      0              1             0
# 1      0              1             0
# 2      0              1             0
# 3      0              0             0
# 4      0              0             0

# %%
from sklearn.model_selection import  train_test_split

X = df.drop(columns=['wage_per_hour'])
y = df[['wage_per_hour']]

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=20)

# %% [markdown]
# Notice no feature preparation or engineering.
#
# ---
# # Train a multi-layer perceptron

# %%
X.shape
# Out:
# (534, 9)

# %%
from tensorflow.keras.models import Sequential        # Helper to build a network from a sequence of layers
from tensorflow.keras.layers import Dense             # Fully-connected layer
from tensorflow.keras.callbacks import EarlyStopping  # To stop training early if val loss stops decreasing

# Create the model (num_features -> 10 -> 10 -> 1)
model = Sequential()
model.add(Dense(10, activation='relu', input_shape=(X.shape[1],)))
model.add(Dense(10, activation='relu'))
model.add(Dense(1))

# Train the model
model.compile(optimizer='adam', loss='mean_squared_error')    # Builds the static computation graph
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=32, 
          callbacks=[EarlyStopping(patience=3)], verbose=1)
# defining 'validation_data' will also print validation loss alongside training loss
# callbacks contain extra little settings or features during training
# EarlyStopping with patience will stop training early if val_loss didnt get lower after 3 epochs (prevent over-fitting)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 0s 9ms/step - loss: 152.1907 - val_loss: 139.7521
# Epoch 2/100
# 14/14 [==============================] - 0s 2ms/step - loss: 109.8217 - val_loss: 99.9930
# Epoch 3/100
# 14/14 [==============================] - 0s 2ms/step - loss: 74.3682 - val_loss: 68.3621
# Epoch 4/100
# 14/14 [==============================] - 0s 2ms/step - loss: 48.3122 - val_loss: 46.2422
# Epoch 5/100
# 14/14 [==============================] - 0s 2ms/step - loss: 32.1346 - val_loss: 33.9482
# Epoch 6/100
# 14/14 [==============================] - 0s 2ms/step - loss: 24.7352 - val_loss: 28.6371
# Epoch 7/100
# 14/14 [==============================] - 0s 2ms/step - loss: 22.6465 - val_loss: 27.1134
# Epoch 8/100
# 14/14 [==============================] - 0s 2ms/step - loss: 22.4429 - val_loss: 26.6226
# Epoch 9/100
# 14/14 [==============================] - 0s 2ms/step - loss: 22.3073 - val_loss: 26.5620
# Epoch 10/100
# 14/14 [==============================] - 0s 2ms/step - loss: 22.1894 - val_loss: 26.4924
# Epoch 11/100
# 14/14 [==============================] - 0s 2ms/step - loss: 22.1375 - val_loss: 26.5249
# Epoch 12/100
# 14/14 [==============================] - 0s 2ms/step - loss: 22.0357 - val_loss: 26.1971
# Epoch 13/100
# 14/14 [==============================] - 0s 2ms/step - loss: 21.9062 - val_loss: 26.2485
# Epoch 14/100
# 14/14 [==============================] - 0s 2ms/step - loss: 21.8323 - val_loss: 26.2500
# Epoch 15/100
# 14/14 [==============================] - 0s 2ms/step - loss: 21.7663 - val_loss: 26.2432

# %% [markdown]
# Notice we don't need to calculate some evaluation metric (on the validation set) after the NN is trained, since it is represented by the calculated loss (val_loss).
#
# We can make predictions using `.predict`. This just runs the input data through the neural network.

# %%
X_val.head()
# Out:
#      union  education_yrs  experience_yrs  age  female  marr  south  \
# 375      0             12               7   25       1     0      0
# 299      0             12              19   37       0     1      0
# 129      0             12              16   34       0     0      1
# 254      0             16              27   49       1     1      0
# 501      0             12              42   60       1     1      0
#
#      manufacturing  construction
# 375              0             0
# 299              0             0
# 129              0             0
# 254              1             0
# 501              0             0

# %%
y_hat = model.predict(X_val.head())
y_hat
# Out:
# 1/1 [==============================] - 0s 51ms/step
# array([[ 7.4691777],
#        [ 8.561876 ],
#        [ 8.21401  ],
#        [10.985247 ],
#        [10.276    ]], dtype=float32)

# %% [markdown]
# ---
# # Comparison to linear regression

# %%
# Create the linear regression model
regression = Sequential()
regression.add(Dense(1, input_shape=(X.shape[1],)))

# Train the model
regression.compile(optimizer='adam', loss='mean_squared_error')
regression.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=32, 
               callbacks=[EarlyStopping(patience=3)], verbose=1)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 0s 6ms/step - loss: 1266.0353 - val_loss: 1167.4885
# Epoch 2/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1194.0160 - val_loss: 1101.7286
# Epoch 3/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1125.2817 - val_loss: 1038.5332
# Epoch 4/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1059.0289 - val_loss: 978.6790
# Epoch 5/100
# 14/14 [==============================] - 0s 2ms/step - loss: 995.8682 - val_loss: 920.7685
# Epoch 6/100
# 14/14 [==============================] - 0s 2ms/step - loss: 935.9144 - val_loss: 865.4071
# Epoch 7/100
# 14/14 [==============================] - 0s 2ms/step - loss: 878.8245 - val_loss: 812.9100
# Epoch 8/100
# 14/14 [==============================] - 0s 2ms/step - loss: 823.7684 - val_loss: 763.3492
# Epoch 9/100
# 14/14 [==============================] - 0s 2ms/step - loss: 772.6053 - val_loss: 715.7355
# Epoch 10/100
# 14/14 [==============================] - 0s 2ms/step - loss: 723.3902 - val_loss: 671.3511
# Epoch 11/100
# 14/14 [==============================] - 0s 2ms/step - loss: 677.1468 - val_loss: 629.9056
# Epoch 12/100
# 14/14 [==============================] - 0s 2ms/step - loss: 634.1038 - val_loss: 589.9056
# Epoch 13/100
# 14/14 [==============================] - 0s 2ms/step - loss: 592.2313 - val_loss: 551.7538
# Epoch 14/100
# 14/14 [==============================] - 0s 2ms/step - loss: